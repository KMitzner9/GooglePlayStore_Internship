# %% [markdown]
# # General EDA with the Google Play Store Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../googleplaystoremaster.csv")
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
pd.unique(df['Category'])
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
pd.unique(df['Content Rating'])
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
pd.unique(df['Genres'])
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
df.describe()

# the max here of 19 is alarming! 
# if the scale is 1-5, this must be a mistake and is likely throwing off our other descriptive statistics
# also this shows me that Rating is the only category that we have as numerical
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
pd.unique(df.duplicated())
# Out:
# array([False,  True])

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().any()
# Out:
# False

# %%
# reset the index after dropping duplicates so the values line up with the positions
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
pd.unique(df['Reviews'])
# Out:
# array([   159,    967,  87510, ...,    603,   1195, 398307])

# %%
### JUST REALIZED THIS IS A COLUMN SHIFT AND ALL VALUES NEED TO BE MOVED ONE TO THE RIGHT. CAN I WRITE A FUNCTION? ###
### MAYBE I SHOULD JUST DROP IT?? ###
df[df['Reviews'] == '3.0M']
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df.loc[9990, ['Reviews']] = 3000000

# %%
df.loc[9990, ['Rating']] = 1.9
df.loc[[9990]]
# Out:
#                                           App Category  Rating  Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9     1.9  3000000
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df.loc[9990, ['Category']] = 'PHOTOGRAPHY'
df.loc[[9990]]
# Out:
#                                           App     Category  Rating  Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame  PHOTOGRAPHY     1.9  3000000
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df[['Reviews']] = df[['Reviews']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  int32
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 1011.6+ KB

# %%
# inspect the number of NaN values in the data set
df.isnull().sum()

# looking pretty slick overall other than the ratings category
# Ratings category has ~10% of the values missing
# Are there a certain number of reviews necessary for ratings to initiate?
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# any columns that are all NaN?
df.isnull().all()
# Out:
# App               False
# Category          False
# Rating            False
# Reviews           False
# Size              False
# Installs          False
# Type              False
# Price             False
# Content Rating    False
# Genres            False
# Last Updated      False
# Current Ver       False
# Android Ver       False
# dtype: bool

# %%
# do we have any rows with all nan?
df.isnull().all(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10353    False
# 10354    False
# 10355    False
# 10356    False
# 10357    False
# Length: 10358, dtype: bool

# %%
# checking our previous list for any true values
df.isnull().all(axis=1).any()
# Out:
# False

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                    App             Category  Rating  Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2       55
# 23              Mcqueen Coloring pages       ART_AND_DESIGN     NaN       61
# 113          Wrinkles and rejuvenation               BEAUTY     NaN      182
# 123             Manicure - nail design               BEAUTY     NaN      119
# 126       Skin Care and Natural Beauty               BEAUTY     NaN      654
# ...                                ...                  ...     ...      ...
# 10341                        Cardio-FR              MEDICAL     NaN       67
# 10342               Naruto & Boruto FR               SOCIAL     NaN        7
# 10348         payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN       38
# 10352                         FR Forms             BUSINESS     NaN        0
# 10355           Parkinson Exercices FR              MEDICAL     NaN        3
#
# ...

# %%
pd.unique(df['Price'])
# lol @ 'Everyone', I guess this one is free!?
# should change all of these to float types and removes the dollar sign
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Type'].drop_duplicates().sort_values()
# Out:
# 9990       0
# 0       Free
# 233     Paid
# 8667     NaN
# Name: Type, dtype: object

# %%
df.iloc[[8667]]
# Out:
#                             App Category  Rating  Reviews                Size  \
# 8667  Command & Conquer: Rivals   FAMILY     NaN        0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 8667        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 8667  Varies with device  Varies with device

# %%
df[df['Type'] =='0']
# Out:
#                                           App     Category  Rating  Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame  PHOTOGRAPHY     1.9  3000000
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
pd.unique(df['Installs'])
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
df['Installs'] = df['Installs'].apply(lambda x: x.replace(',', ''))

# %%
df['Size'].drop_duplicates().sort_values()
# Out:
# 9990                1,000+
# 5314                  1.0M
# 87                    1.1M
# 43                    1.2M
# 2137                  1.3M
#                ...
# 1463                   98M
# 9920                  992k
# 8402                  994k
# 1323                   99M
# 37      Varies with device
# Name: Size, Length: 462, dtype: object

# %%
df['Rating'].drop_duplicates().sort_values()
# Out:
# 559     1.0
# 9600    1.2
# 5549    1.4
# 6657    1.5
# 4450    1.6
# 3559    1.7
# 3709    1.8
# 471     1.9
# 3563    2.0
# 5451    2.1
# 3525    2.2
# 2129    2.3
# 3921    2.4
# 473     2.5
# 430     2.6
# 545     2.7
# 481     2.8
# 612     2.9
# 467     3.0
# 209     3.1
# 15      3.2
# 159     3.3
# 176     3.4
# 184     3.5
# 71      3.6
# 84      3.7
# 6       3.8
# 1       3.9
# 20      4.0
# 0       4.1
# 12      4.2
# 4       4.3
# 5       4.4
# 3       4.5
# 13      4.6
# 2       4.7
# 25      4.8
# 55      4.9
# 296     5.0
# 23      NaN
# Name: Rating, dtype: float64

# %%
df.loc[[23]]
# Out:
#                        App        Category  Rating  Reviews  Size Installs  \
# 23  Mcqueen Coloring pages  ART_AND_DESIGN     NaN       61  7.0M  100000+
#
#     Type Price Content Rating                           Genres   Last Updated  \
# 23  Free     0       Everyone  Art & Design;Action & Adventure  March 7, 2018
#
#    Current Ver Android Ver
# 23       1.0.0  4.1 and up

# %%
ent_df = df.loc[ df['Category'] == 'ENTERTAINMENT' , : ]
ent_df.head()
# Out:
#                             App       Category  Rating  Reviews  \
# 745                     Netflix  ENTERTAINMENT     4.4  5456208
# 746     Complete Spanish Movies  ENTERTAINMENT     4.0    11656
# 747     Pluto TV - It’s Free TV  ENTERTAINMENT     4.2    28948
# 748  Tubi TV - Free Movies & TV  ENTERTAINMENT     4.3   296771
# 749                YouTube Kids  ENTERTAINMENT     4.5   470089
#
#                    Size    Installs  Type Price Content Rating  \
# 745  Varies with device  100000000+  Free     0           Teen
# 746                4.5M    1000000+  Free     0       Everyone
# 747  Varies with device    1000000+  Free     0           Teen
# 748                 11M   10000000+  Free     0           Teen
# 749  Varies with device   50000000+  Free     0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 745                Entertainment     July 31, 2018  Varies with device
# ...

# %%
ent_content = ent_df.groupby('Content Rating').count()
ent_content
# Out:
#                 App  Category  Rating  Reviews  Size  Installs  Type  Price  \
# Content Rating
# Everyone         37        37      37       37    37        37    37     37
# Everyone 10+      2         2       2        2     2         2     2      2
# Mature 17+        6         6       6        6     6         6     6      6
# Teen             66        66      66       66    66        66    66     66
#
#                 Genres  Last Updated  Current Ver  Android Ver
# Content Rating
# Everyone            37            37           37           37
# Everyone 10+         2             2            2            2
# Mature 17+           6             6            6            6
# Teen                66            66           66           66

# %%
pd.unique(ent_df['Content Rating'])
# Out:
# array(['Teen', 'Everyone', 'Mature 17+', 'Everyone 10+'], dtype=object)

# %%
ent_content = ent_content.iloc[:, 0]
ent_content
# Out:
# Content Rating
# Everyone        37
# Everyone 10+     2
# Mature 17+       6
# Teen            66
# Name: App, dtype: int64

# %%
ent_content = pd.DataFrame(ent_content)
ent_content
# Out:
#                 App
# Content Rating
# Everyone         37
# Everyone 10+      2
# Mature 17+        6
# Teen             66

# %%
ent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111 entries, 745 to 855
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             111 non-null    object
#  1   Category        111 non-null    object
#  2   Rating          111 non-null    float64
#  3   Reviews         111 non-null    int32
#  4   Size            111 non-null    object
#  5   Installs        111 non-null    object
#  6   Type            111 non-null    object
#  7   Price           111 non-null    object
#  8   Content Rating  111 non-null    object
#  9   Genres          111 non-null    object
#  10  Last Updated    111 non-null    object
#  11  Current Ver     111 non-null    object
#  12  Android Ver     111 non-null    object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 11.7+ KB

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df.loc[df['Size'] == 'Varies with device', :]
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10231  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10243                                          Posta App  MAPS_AND_NAVIGATION
# 10283                    Chat For Strangers - Video Chat               SOCIAL
# 10343          Frim: get new friends on local chat rooms               SOCIAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
df.loc[ df['Size'] == '1,000+' , : ]
# Out:
#                                           App     Category  Rating  Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame  PHOTOGRAPHY     1.9  3000000
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df.drop(9990, inplace=True)

# %%
def new_size(x):
        if 'k' in x:
            return (float(x.replace('k', ''))) * 1000
        if 'M' in x:
            return (float(x.replace('M', ''))) * 1000000
    
df['Size'] = df['Size'].apply(new_size)

# %%
df['Size'].unique()
# Out:
# array([1.90e+07, 1.40e+07, 8.70e+06, 2.50e+07, 2.80e+06, 5.60e+06,
#        2.90e+07, 3.30e+07, 3.10e+06, 2.80e+07, 1.20e+07, 2.00e+07,
#        2.10e+07, 3.70e+07, 2.70e+06, 5.50e+06, 1.70e+07, 3.90e+07,
#        3.10e+07, 4.20e+06, 7.00e+06, 2.30e+07, 6.00e+06, 6.10e+06,
#        4.60e+06, 9.20e+06, 5.20e+06, 1.10e+07, 2.40e+07,      nan,
#        9.40e+06, 1.50e+07, 1.00e+07, 1.20e+06, 2.60e+07, 8.00e+06,
#        7.90e+06, 5.60e+07, 5.70e+07, 3.50e+07, 5.40e+07, 2.01e+05,
#        3.60e+06, 5.70e+06, 8.60e+06, 2.40e+06, 2.70e+07, 2.50e+06,
#        1.60e+07, 3.40e+06, 8.90e+06, 3.90e+06, 2.90e+06, 3.80e+07,
#        3.20e+07, 5.40e+06, 1.80e+07, 1.10e+06, 2.20e+06, 4.50e+06,
#        9.80e+06, 5.20e+07, 9.00e+06, 6.70e+06, 3.00e+07, 2.60e+06,
#        7.10e+06, 3.70e+06, 2.20e+07, 7.40e+06, 6.40e+06, 3.20e+06,
#        8.20e+06, 9.90e+06, 4.90e+06, 9.50e+06, 5.00e+06, 5.90e+06,
#        1.30e+07, 7.30e+07, 6.80e+06, 3.50e+06, 4.00e+06, 2.30e+06,
# ...

# %%
cdf = pd.read_csv('clean_googleplaystoremaster.csv')
cdf
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
